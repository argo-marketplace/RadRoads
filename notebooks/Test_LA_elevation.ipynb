# %%
import pandas as pd
import os 
import osmnx as ox
import networkx as nx
import numpy as np
import apiclient.discovery

# %%
api_key = 'AIzaSyCg_Q0TGRGnCcQd9qsuhTjXjfpJpllGz68'

# %%
place = 'Los Angeles'
place_query = {'city':'Los Angeles', 'state':'California', 'country':'USA'}
G = ox.graph_from_place(place_query, network_type='drive')

# %%
G = ox.add_node_elevations(G, api_key=api_key)
G = ox.add_edge_grades(G)

# %%
G_proj = ox.project_graph(G)

# %%
nc = ox.get_node_colors_by_attr(G_proj, 'elevation', cmap='plasma', num_bins=20)
fig, ax = ox.plot_graph(G_proj, fig_height=6, node_color=nc, node_size=12, node_zorder=2, edge_color='#dddddd')
