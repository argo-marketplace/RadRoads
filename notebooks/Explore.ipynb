# %%
#Importing necessary packages

import geopandas as gpd
import pandas as pd
import matplotlib.pylab as plt
import fiona
import osmnx as ox
import networkx as nx

# %matplotlib inline

# %%
Boulder = ox.graph_from_place('Boulder, Colorado, USA')
Boulder_projected = ox.project_graph(Boulder)
fig, ax = ox.plot_graph(Boulder_projected)

# %%
ox.save_graph_shapefile(Boulder_projected, filename='Boulder-shape')

# %%
ox.stats.basic_stats(Boulder_projected)
# Out:
# {'circuity_avg': 1.4272477214381237e-05,
#  'clean_intersection_count': None,
#  'clean_intersection_density_km': None,
#  'edge_density_km': None,
#  'edge_length_avg': 65.38400344921989,
#  'edge_length_total': 1923401.2294657014,
#  'intersection_count': 9313,
#  'intersection_density_km': None,
#  'k_avg': 5.47293023255814,
#  'm': 29417,
#  'n': 10750,
#  'node_density_km': None,
#  'self_loop_proportion': 0.006968759560798178,
#  'street_density_km': None,
#  'street_length_avg': 65.664401538654005,
#  'street_length_total': 1047215.8757384541,
#  'street_segments_count': 15948,
#  'streets_per_node_avg': 2.970046511627907,
#  'streets_per_node_counts': {0: 0,
#   1: 1437,
#   2: 66,
#   3: 6732,
#   4: 2424,
#   5: 80,
#   6: 10,
#   7: 1},
#  'streets_per_node_proportion': {0: 0.0,
#   1: 0.13367441860465115,
#   2: 0.00613953488372093,
#   3: 0.6262325581395349,
#   4: 0.22548837209302325,
#   5: 0.0074418604651162795,
#   6: 0.0009302325581395349,
#   7: 9.302325581395348e-05}}
